# %%
# %load_ext autoreload
# %autoreload
import scrapfin as scf
import pandas as pd
import asyncio
from functools import partial
from IPython.core.debugger import set_trace
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
scf.yahoo('ACWI','SPY','MTUM', start='2019-01-01', what='adjclose')
# Out:
# C:\Users\Sejin\Anaconda3\lib\site-packages\yahoo_fin\stock_info.py:82: FutureWarning: 'date' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   result = result.sort_values("date")
#                  ACWI         SPY        MTUM
# date
# 2019-01-02  64.139999  250.179993   99.559998
# 2019-01-03  63.049999  244.210007   96.809998
# 2019-01-04  65.059998  252.389999  100.050003
# 2019-01-07  65.459999  254.380005  101.010002
# 2019-01-08  65.940002  256.769989  102.260002
# 2019-01-09  66.550003  257.970001  102.860001
# 2019-01-10  66.860001  258.880005  103.000000
# 2019-01-11  66.620003  258.980011  103.070000
# 2019-01-14  66.239998  257.399994  102.169998
# 2019-01-15  66.839996  260.350006  103.779999
# 2019-01-16  67.029999  260.980011  103.620003
# 2019-01-17  67.519997  262.959991  104.410004
# 2019-01-18  68.230003  266.459991  105.510002
# 2019-01-22  67.330002  262.859985  104.349998
# ...

# %%
alloc = scf.etfdb_alloc('ACWI','SPY','QUAL'); alloc
# Out:
# ...
#                                         ACWI    SPY   QUAL
# Asset       Common equity              98.05  99.92  99.69
#             ETF Cash Component          1.27   0.08   0.31
#             Preferred stock             0.68   0.00   0.00
# Country     Argentina                   0.03   0.00   0.00
#             Australia                   2.14   0.00   0.00
#             Austria                     0.08   0.00   0.00
#             Belgium                     0.31   0.00   0.00
#             Brazil                      0.80   0.00   0.00
#             Canada                      3.09   0.00   0.00
#             Chile                       0.11   0.00   0.00
#             China                       3.41   0.00   0.00
#             Colombia                    0.05   0.00   0.00
#             Czech Republic              0.02   0.00   0.00
#             Denmark                     0.56   0.00   0.00
#             Egypt                       0.01   0.00   0.00
# ...
